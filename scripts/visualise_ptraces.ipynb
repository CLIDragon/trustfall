# %%
data = """
time: 401µs
time (agg): 276.1µs
Opid(1) None Call(ResolveStartingVertices(Vid(1)))
- Opid(14) Some(2.3µs) YieldFrom(ResolveStartingVertices)
- Opid(56) Some(0ns) YieldFrom(ResolveStartingVertices)
- Opid(98) Some(100ns) YieldFrom(ResolveStartingVertices)
- Opid(147) Some(0ns) YieldFrom(ResolveStartingVertices)
- Opid(189) Some(0ns) YieldFrom(ResolveStartingVertices)
- Opid(231) None OutputIteratorExhausted
Opid(2) None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
- Opid(13) None AdvanceInputIterator
- Opid(15) Some(10µs) YieldInto
- Opid(16) Some(31.1µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(17) Some(400ns) YieldFrom(ResolveNeighborsInner)
-- Opid(54) None OutputIteratorExhausted
- Opid(55) None AdvanceInputIterator
- Opid(57) Some(300ns) YieldInto
- Opid(58) Some(600ns) YieldFrom(ResolveNeighborsOuter)
-- Opid(59) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(96) None OutputIteratorExhausted
- Opid(97) None AdvanceInputIterator
- Opid(99) Some(500ns) YieldInto
- Opid(100) Some(1µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(101) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(145) None OutputIteratorExhausted
- Opid(146) None AdvanceInputIterator
- Opid(148) Some(200ns) YieldInto
- Opid(149) Some(700ns) YieldFrom(ResolveNeighborsOuter)
-- Opid(150) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(187) None OutputIteratorExhausted
- Opid(188) None AdvanceInputIterator
- Opid(190) Some(400ns) YieldInto
- Opid(191) Some(900ns) YieldFrom(ResolveNeighborsOuter)
-- Opid(192) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(229) None OutputIteratorExhausted
- Opid(230) None AdvanceInputIterator
- Opid(232) None InputIteratorExhausted
- Opid(233) None OutputIteratorExhausted
Opid(3) None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
- Opid(12) None AdvanceInputIterator
- Opid(18) Some(40.9µs) YieldInto
- Opid(19) Some(46.3µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(20) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(52) None OutputIteratorExhausted
- Opid(53) None AdvanceInputIterator
- Opid(60) Some(3.6µs) YieldInto
- Opid(61) Some(4.3µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(62) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(94) None OutputIteratorExhausted
- Opid(95) None AdvanceInputIterator
- Opid(102) Some(3.8µs) YieldInto
- Opid(103) Some(4.7µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(104) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(143) None OutputIteratorExhausted
- Opid(144) None AdvanceInputIterator
- Opid(151) Some(1.8µs) YieldInto
- Opid(152) Some(2.6µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(153) Some(100ns) YieldFrom(ResolveNeighborsInner)
-- Opid(185) None OutputIteratorExhausted
- Opid(186) None AdvanceInputIterator
- Opid(193) Some(3.3µs) YieldInto
- Opid(194) Some(4µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(195) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(227) None OutputIteratorExhausted
- Opid(228) None AdvanceInputIterator
- Opid(234) None InputIteratorExhausted
- Opid(235) None OutputIteratorExhausted
Opid(4) None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
- Opid(11) None AdvanceInputIterator
- Opid(21) Some(49.9µs) YieldInto
- Opid(22) Some(54.4µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(23) Some(100ns) YieldFrom(ResolveNeighborsInner)
-- Opid(50) None OutputIteratorExhausted
- Opid(51) None AdvanceInputIterator
- Opid(63) Some(7.5µs) YieldInto
- Opid(64) Some(8.7µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(65) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(92) None OutputIteratorExhausted
- Opid(93) None AdvanceInputIterator
- Opid(105) Some(7.9µs) YieldInto
- Opid(106) Some(9.1µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(107) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(141) None OutputIteratorExhausted
- Opid(142) None AdvanceInputIterator
- Opid(154) Some(4.5µs) YieldInto
- Opid(155) Some(5.9µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(156) Some(100ns) YieldFrom(ResolveNeighborsInner)
-- Opid(183) None OutputIteratorExhausted
- Opid(184) None AdvanceInputIterator
- Opid(196) Some(21.5µs) YieldInto
- Opid(197) Some(22.3µs) YieldFrom(ResolveNeighborsOuter)
-- Opid(198) Some(0ns) YieldFrom(ResolveNeighborsInner)
-- Opid(225) None OutputIteratorExhausted
- Opid(226) None AdvanceInputIterator
- Opid(236) None InputIteratorExhausted
- Opid(237) None OutputIteratorExhausted
Opid(5) None Call(ResolveCoercion(Vid(2), "Number", "Prime"))
- Opid(10) None AdvanceInputIterator
- Opid(24) Some(69.1µs) YieldInto
- Opid(25) Some(78.9µs) YieldFrom(ResolveCoercion)
- Opid(26) None AdvanceInputIterator
- Opid(27) Some(0ns) YieldInto
- Opid(28) Some(800ns) YieldFrom(ResolveCoercion)
- Opid(29) None AdvanceInputIterator
- Opid(30) Some(0ns) YieldInto
- Opid(31) Some(600ns) YieldFrom(ResolveCoercion)
- Opid(39) None AdvanceInputIterator
- Opid(40) Some(100ns) YieldInto
- Opid(41) Some(800ns) YieldFrom(ResolveCoercion)
- Opid(49) None AdvanceInputIterator
- Opid(66) Some(17.5µs) YieldInto
- Opid(67) Some(17.9µs) YieldFrom(ResolveCoercion)
- Opid(68) None AdvanceInputIterator
- Opid(69) Some(0ns) YieldInto
- Opid(70) Some(600ns) YieldFrom(ResolveCoercion)
- Opid(78) None AdvanceInputIterator
- Opid(79) Some(0ns) YieldInto
- Opid(80) Some(600ns) YieldFrom(ResolveCoercion)
- Opid(88) None AdvanceInputIterator
- Opid(89) Some(100ns) YieldInto
- Opid(90) Some(5µs) YieldFrom(ResolveCoercion)
- Opid(91) None AdvanceInputIterator
- Opid(108) Some(11.3µs) YieldInto
- Opid(109) Some(11.9µs) YieldFrom(ResolveCoercion)
- Opid(117) None AdvanceInputIterator
- Opid(118) Some(100ns) YieldInto
- Opid(119) Some(2.1µs) YieldFrom(ResolveCoercion)
- Opid(127) None AdvanceInputIterator
- Opid(128) Some(0ns) YieldInto
- Opid(129) Some(400ns) YieldFrom(ResolveCoercion)
- Opid(130) None AdvanceInputIterator
- Opid(131) Some(100ns) YieldInto
- Opid(132) Some(600ns) YieldFrom(ResolveCoercion)
- Opid(140) None AdvanceInputIterator
- Opid(157) Some(10.6µs) YieldInto
- Opid(158) Some(11µs) YieldFrom(ResolveCoercion)
- Opid(166) None AdvanceInputIterator
- Opid(167) Some(0ns) YieldInto
- Opid(168) Some(700ns) YieldFrom(ResolveCoercion)
- Opid(169) None AdvanceInputIterator
- Opid(170) Some(100ns) YieldInto
- Opid(171) Some(400ns) YieldFrom(ResolveCoercion)
- Opid(179) None AdvanceInputIterator
- Opid(180) Some(0ns) YieldInto
- Opid(181) Some(900ns) YieldFrom(ResolveCoercion)
- Opid(182) None AdvanceInputIterator
- Opid(199) Some(24.4µs) YieldInto
- Opid(200) Some(27.5µs) YieldFrom(ResolveCoercion)
- Opid(201) None AdvanceInputIterator
- Opid(202) Some(100ns) YieldInto
- Opid(203) Some(600ns) YieldFrom(ResolveCoercion)
- Opid(211) None AdvanceInputIterator
- Opid(212) Some(0ns) YieldInto
- Opid(213) Some(400ns) YieldFrom(ResolveCoercion)
- Opid(214) None AdvanceInputIterator
- Opid(215) Some(0ns) YieldInto
- Opid(216) Some(600ns) YieldFrom(ResolveCoercion)
- Opid(224) None AdvanceInputIterator
- Opid(238) None InputIteratorExhausted
- Opid(239) None OutputIteratorExhausted
Opid(6) None Call(ResolveProperty(Vid(2), "Prime", "value"))
- Opid(9) None AdvanceInputIterator
- Opid(32) Some(96.7µs) YieldInto
- Opid(33) Some(108.2µs) YieldFrom(ResolveProperty)
- Opid(38) None AdvanceInputIterator
- Opid(42) Some(1.4µs) YieldInto
- Opid(43) Some(1.8µs) YieldFrom(ResolveProperty)
- Opid(48) None AdvanceInputIterator
- Opid(71) Some(19.1µs) YieldInto
- Opid(72) Some(19.5µs) YieldFrom(ResolveProperty)
- Opid(77) None AdvanceInputIterator
- Opid(81) Some(900ns) YieldInto
- Opid(82) Some(1.2µs) YieldFrom(ResolveProperty)
- Opid(87) None AdvanceInputIterator
- Opid(110) Some(17.8µs) YieldInto
- Opid(111) Some(19.8µs) YieldFrom(ResolveProperty)
- Opid(116) None AdvanceInputIterator
- Opid(120) Some(7.4µs) YieldInto
- Opid(121) Some(8.2µs) YieldFrom(ResolveProperty)
- Opid(126) None AdvanceInputIterator
- Opid(133) Some(1.9µs) YieldInto
- Opid(134) Some(2.4µs) YieldFrom(ResolveProperty)
- Opid(139) None AdvanceInputIterator
- Opid(159) Some(11.3µs) YieldInto
- Opid(160) Some(11.8µs) YieldFrom(ResolveProperty)
- Opid(165) None AdvanceInputIterator
- Opid(172) Some(1.9µs) YieldInto
- Opid(173) Some(2.2µs) YieldFrom(ResolveProperty)
- Opid(178) None AdvanceInputIterator
- Opid(204) Some(30.2µs) YieldInto
- Opid(205) Some(30.5µs) YieldFrom(ResolveProperty)
- Opid(210) None AdvanceInputIterator
- Opid(217) Some(1.9µs) YieldInto
- Opid(218) Some(2.3µs) YieldFrom(ResolveProperty)
- Opid(223) None AdvanceInputIterator
- Opid(240) None InputIteratorExhausted
- Opid(241) None OutputIteratorExhausted
Opid(7) None Call(ResolveProperty(Vid(1), "Number", "value"))
- Opid(8) None AdvanceInputIterator
- Opid(34) Some(115.9µs) YieldInto
- Opid(35) Some(120.3µs) YieldFrom(ResolveProperty)
- Opid(37) None AdvanceInputIterator
- Opid(44) Some(2.4µs) YieldInto
- Opid(45) Some(3.1µs) YieldFrom(ResolveProperty)
- Opid(47) None AdvanceInputIterator
- Opid(73) Some(19.8µs) YieldInto
- Opid(74) Some(25.3µs) YieldFrom(ResolveProperty)
- Opid(76) None AdvanceInputIterator
- Opid(83) Some(3.4µs) YieldInto
- Opid(84) Some(3.7µs) YieldFrom(ResolveProperty)
- Opid(86) None AdvanceInputIterator
- Opid(112) Some(20.2µs) YieldInto
- Opid(113) Some(20.5µs) YieldFrom(ResolveProperty)
- Opid(115) None AdvanceInputIterator
- Opid(122) Some(8.6µs) YieldInto
- Opid(123) Some(9.2µs) YieldFrom(ResolveProperty)
- Opid(125) None AdvanceInputIterator
- Opid(135) Some(2.8µs) YieldInto
- Opid(136) Some(3.4µs) YieldFrom(ResolveProperty)
- Opid(138) None AdvanceInputIterator
- Opid(161) Some(16.8µs) YieldInto
- Opid(162) Some(18.7µs) YieldFrom(ResolveProperty)
- Opid(164) None AdvanceInputIterator
- Opid(174) Some(3.1µs) YieldInto
- Opid(175) Some(3.4µs) YieldFrom(ResolveProperty)
- Opid(177) None AdvanceInputIterator
- Opid(206) Some(35.1µs) YieldInto
- Opid(207) Some(35.7µs) YieldFrom(ResolveProperty)
- Opid(209) None AdvanceInputIterator
- Opid(219) Some(2.8µs) YieldInto
- Opid(220) Some(3.2µs) YieldFrom(ResolveProperty)
- Opid(222) None AdvanceInputIterator
- Opid(242) None InputIteratorExhausted
- Opid(243) None OutputIteratorExhausted
Opid(36) Some(141.2µs) ProduceQueryResult
Opid(46) Some(3.9µs) ProduceQueryResult
Opid(75) Some(26.2µs) ProduceQueryResult
Opid(85) Some(4.6µs) ProduceQueryResult
Opid(114) Some(21.1µs) ProduceQueryResult
Opid(124) Some(9.9µs) ProduceQueryResult
Opid(137) Some(4.2µs) ProduceQueryResult
Opid(163) Some(19.4µs) ProduceQueryResult
Opid(176) Some(5.3µs) ProduceQueryResult
Opid(208) Some(36.4µs) ProduceQueryResult
Opid(221) Some(3.9µs) ProduceQueryResult

Opid(1) None None Call(ResolveStartingVertices(Vid(1)))
Opid(2) None None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
Opid(3) None None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
Opid(4) None None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
Opid(5) None None Call(ResolveCoercion(Vid(2), "Number", "Prime"))
Opid(6) None None Call(ResolveProperty(Vid(2), "Prime", "value"))
Opid(7) None None Call(ResolveProperty(Vid(1), "Number", "value"))
Opid(8) Some(Opid(7)) None AdvanceInputIterator
Opid(9) Some(Opid(6)) None AdvanceInputIterator
Opid(10) Some(Opid(5)) None AdvanceInputIterator
Opid(11) Some(Opid(4)) None AdvanceInputIterator
Opid(12) Some(Opid(3)) None AdvanceInputIterator
Opid(13) Some(Opid(2)) None AdvanceInputIterator
Opid(14) Some(Opid(1)) Some(2.3µs) YieldFrom(ResolveStartingVertices)
Opid(15) Some(Opid(2)) Some(10µs) YieldInto
Opid(16) Some(Opid(2)) Some(31.1µs) YieldFrom(ResolveNeighborsOuter)
Opid(17) Some(Opid(16)) Some(400ns) YieldFrom(ResolveNeighborsInner)
Opid(18) Some(Opid(3)) Some(40.9µs) YieldInto
Opid(19) Some(Opid(3)) Some(46.3µs) YieldFrom(ResolveNeighborsOuter)
Opid(20) Some(Opid(19)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(21) Some(Opid(4)) Some(49.9µs) YieldInto
Opid(22) Some(Opid(4)) Some(54.4µs) YieldFrom(ResolveNeighborsOuter)
Opid(23) Some(Opid(22)) Some(100ns) YieldFrom(ResolveNeighborsInner)
Opid(24) Some(Opid(5)) Some(69.1µs) YieldInto
Opid(25) Some(Opid(5)) Some(78.9µs) YieldFrom(ResolveCoercion)
Opid(26) Some(Opid(5)) None AdvanceInputIterator
Opid(27) Some(Opid(5)) Some(0ns) YieldInto
Opid(28) Some(Opid(5)) Some(800ns) YieldFrom(ResolveCoercion)
Opid(29) Some(Opid(5)) None AdvanceInputIterator
Opid(30) Some(Opid(5)) Some(0ns) YieldInto
Opid(31) Some(Opid(5)) Some(600ns) YieldFrom(ResolveCoercion)
Opid(32) Some(Opid(6)) Some(96.7µs) YieldInto
Opid(33) Some(Opid(6)) Some(108.2µs) YieldFrom(ResolveProperty)
Opid(34) Some(Opid(7)) Some(115.9µs) YieldInto
Opid(35) Some(Opid(7)) Some(120.3µs) YieldFrom(ResolveProperty)
Opid(36) None Some(141.2µs) ProduceQueryResult

Opid(37) Some(Opid(7)) None AdvanceInputIterator
Opid(38) Some(Opid(6)) None AdvanceInputIterator
Opid(39) Some(Opid(5)) None AdvanceInputIterator
Opid(40) Some(Opid(5)) Some(100ns) YieldInto
Opid(41) Some(Opid(5)) Some(800ns) YieldFrom(ResolveCoercion)
Opid(42) Some(Opid(6)) Some(1.4µs) YieldInto
Opid(43) Some(Opid(6)) Some(1.8µs) YieldFrom(ResolveProperty)
Opid(44) Some(Opid(7)) Some(2.4µs) YieldInto
Opid(45) Some(Opid(7)) Some(3.1µs) YieldFrom(ResolveProperty)
Opid(46) None Some(3.9µs) ProduceQueryResult

Opid(47) Some(Opid(7)) None AdvanceInputIterator
Opid(48) Some(Opid(6)) None AdvanceInputIterator
Opid(49) Some(Opid(5)) None AdvanceInputIterator
Opid(50) Some(Opid(22)) None OutputIteratorExhausted
Opid(51) Some(Opid(4)) None AdvanceInputIterator
Opid(52) Some(Opid(19)) None OutputIteratorExhausted
Opid(53) Some(Opid(3)) None AdvanceInputIterator
Opid(54) Some(Opid(16)) None OutputIteratorExhausted
Opid(55) Some(Opid(2)) None AdvanceInputIterator
Opid(56) Some(Opid(1)) Some(0ns) YieldFrom(ResolveStartingVertices)
Opid(57) Some(Opid(2)) Some(300ns) YieldInto
Opid(58) Some(Opid(2)) Some(600ns) YieldFrom(ResolveNeighborsOuter)
Opid(59) Some(Opid(58)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(60) Some(Opid(3)) Some(3.6µs) YieldInto
Opid(61) Some(Opid(3)) Some(4.3µs) YieldFrom(ResolveNeighborsOuter)
Opid(62) Some(Opid(61)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(63) Some(Opid(4)) Some(7.5µs) YieldInto
Opid(64) Some(Opid(4)) Some(8.7µs) YieldFrom(ResolveNeighborsOuter)
Opid(65) Some(Opid(64)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(66) Some(Opid(5)) Some(17.5µs) YieldInto
Opid(67) Some(Opid(5)) Some(17.9µs) YieldFrom(ResolveCoercion)
Opid(68) Some(Opid(5)) None AdvanceInputIterator
Opid(69) Some(Opid(5)) Some(0ns) YieldInto
Opid(70) Some(Opid(5)) Some(600ns) YieldFrom(ResolveCoercion)
Opid(71) Some(Opid(6)) Some(19.1µs) YieldInto
Opid(72) Some(Opid(6)) Some(19.5µs) YieldFrom(ResolveProperty)
Opid(73) Some(Opid(7)) Some(19.8µs) YieldInto
Opid(74) Some(Opid(7)) Some(25.3µs) YieldFrom(ResolveProperty)
Opid(75) None Some(26.2µs) ProduceQueryResult

Opid(76) Some(Opid(7)) None AdvanceInputIterator
Opid(77) Some(Opid(6)) None AdvanceInputIterator
Opid(78) Some(Opid(5)) None AdvanceInputIterator
Opid(79) Some(Opid(5)) Some(0ns) YieldInto
Opid(80) Some(Opid(5)) Some(600ns) YieldFrom(ResolveCoercion)
Opid(81) Some(Opid(6)) Some(900ns) YieldInto
Opid(82) Some(Opid(6)) Some(1.2µs) YieldFrom(ResolveProperty)
Opid(83) Some(Opid(7)) Some(3.4µs) YieldInto
Opid(84) Some(Opid(7)) Some(3.7µs) YieldFrom(ResolveProperty)
Opid(85) None Some(4.6µs) ProduceQueryResult

Opid(86) Some(Opid(7)) None AdvanceInputIterator
Opid(87) Some(Opid(6)) None AdvanceInputIterator
Opid(88) Some(Opid(5)) None AdvanceInputIterator
Opid(89) Some(Opid(5)) Some(100ns) YieldInto
Opid(90) Some(Opid(5)) Some(5µs) YieldFrom(ResolveCoercion)
Opid(91) Some(Opid(5)) None AdvanceInputIterator
Opid(92) Some(Opid(64)) None OutputIteratorExhausted
Opid(93) Some(Opid(4)) None AdvanceInputIterator
Opid(94) Some(Opid(61)) None OutputIteratorExhausted
Opid(95) Some(Opid(3)) None AdvanceInputIterator
Opid(96) Some(Opid(58)) None OutputIteratorExhausted
Opid(97) Some(Opid(2)) None AdvanceInputIterator
Opid(98) Some(Opid(1)) Some(100ns) YieldFrom(ResolveStartingVertices)
Opid(99) Some(Opid(2)) Some(500ns) YieldInto
Opid(100) Some(Opid(2)) Some(1µs) YieldFrom(ResolveNeighborsOuter)
Opid(101) Some(Opid(100)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(102) Some(Opid(3)) Some(3.8µs) YieldInto
Opid(103) Some(Opid(3)) Some(4.7µs) YieldFrom(ResolveNeighborsOuter)
Opid(104) Some(Opid(103)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(105) Some(Opid(4)) Some(7.9µs) YieldInto
Opid(106) Some(Opid(4)) Some(9.1µs) YieldFrom(ResolveNeighborsOuter)
Opid(107) Some(Opid(106)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(108) Some(Opid(5)) Some(11.3µs) YieldInto
Opid(109) Some(Opid(5)) Some(11.9µs) YieldFrom(ResolveCoercion)
Opid(110) Some(Opid(6)) Some(17.8µs) YieldInto
Opid(111) Some(Opid(6)) Some(19.8µs) YieldFrom(ResolveProperty)
Opid(112) Some(Opid(7)) Some(20.2µs) YieldInto
Opid(113) Some(Opid(7)) Some(20.5µs) YieldFrom(ResolveProperty)
Opid(114) None Some(21.1µs) ProduceQueryResult

Opid(115) Some(Opid(7)) None AdvanceInputIterator
Opid(116) Some(Opid(6)) None AdvanceInputIterator
Opid(117) Some(Opid(5)) None AdvanceInputIterator
Opid(118) Some(Opid(5)) Some(100ns) YieldInto
Opid(119) Some(Opid(5)) Some(2.1µs) YieldFrom(ResolveCoercion)
Opid(120) Some(Opid(6)) Some(7.4µs) YieldInto
Opid(121) Some(Opid(6)) Some(8.2µs) YieldFrom(ResolveProperty)
Opid(122) Some(Opid(7)) Some(8.6µs) YieldInto
Opid(123) Some(Opid(7)) Some(9.2µs) YieldFrom(ResolveProperty)
Opid(124) None Some(9.9µs) ProduceQueryResult

Opid(125) Some(Opid(7)) None AdvanceInputIterator
Opid(126) Some(Opid(6)) None AdvanceInputIterator
Opid(127) Some(Opid(5)) None AdvanceInputIterator
Opid(128) Some(Opid(5)) Some(0ns) YieldInto
Opid(129) Some(Opid(5)) Some(400ns) YieldFrom(ResolveCoercion)
Opid(130) Some(Opid(5)) None AdvanceInputIterator
Opid(131) Some(Opid(5)) Some(100ns) YieldInto
Opid(132) Some(Opid(5)) Some(600ns) YieldFrom(ResolveCoercion)
Opid(133) Some(Opid(6)) Some(1.9µs) YieldInto
Opid(134) Some(Opid(6)) Some(2.4µs) YieldFrom(ResolveProperty)
Opid(135) Some(Opid(7)) Some(2.8µs) YieldInto
Opid(136) Some(Opid(7)) Some(3.4µs) YieldFrom(ResolveProperty)
Opid(137) None Some(4.2µs) ProduceQueryResult

Opid(138) Some(Opid(7)) None AdvanceInputIterator
Opid(139) Some(Opid(6)) None AdvanceInputIterator
Opid(140) Some(Opid(5)) None AdvanceInputIterator
Opid(141) Some(Opid(106)) None OutputIteratorExhausted
Opid(142) Some(Opid(4)) None AdvanceInputIterator
Opid(143) Some(Opid(103)) None OutputIteratorExhausted
Opid(144) Some(Opid(3)) None AdvanceInputIterator
Opid(145) Some(Opid(100)) None OutputIteratorExhausted
Opid(146) Some(Opid(2)) None AdvanceInputIterator
Opid(147) Some(Opid(1)) Some(0ns) YieldFrom(ResolveStartingVertices)
Opid(148) Some(Opid(2)) Some(200ns) YieldInto
Opid(149) Some(Opid(2)) Some(700ns) YieldFrom(ResolveNeighborsOuter)
Opid(150) Some(Opid(149)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(151) Some(Opid(3)) Some(1.8µs) YieldInto
Opid(152) Some(Opid(3)) Some(2.6µs) YieldFrom(ResolveNeighborsOuter)
Opid(153) Some(Opid(152)) Some(100ns) YieldFrom(ResolveNeighborsInner)
Opid(154) Some(Opid(4)) Some(4.5µs) YieldInto
Opid(155) Some(Opid(4)) Some(5.9µs) YieldFrom(ResolveNeighborsOuter)
Opid(156) Some(Opid(155)) Some(100ns) YieldFrom(ResolveNeighborsInner)
Opid(157) Some(Opid(5)) Some(10.6µs) YieldInto
Opid(158) Some(Opid(5)) Some(11µs) YieldFrom(ResolveCoercion)
Opid(159) Some(Opid(6)) Some(11.3µs) YieldInto
Opid(160) Some(Opid(6)) Some(11.8µs) YieldFrom(ResolveProperty)
Opid(161) Some(Opid(7)) Some(16.8µs) YieldInto
Opid(162) Some(Opid(7)) Some(18.7µs) YieldFrom(ResolveProperty)
Opid(163) None Some(19.4µs) ProduceQueryResult

Opid(164) Some(Opid(7)) None AdvanceInputIterator
Opid(165) Some(Opid(6)) None AdvanceInputIterator
Opid(166) Some(Opid(5)) None AdvanceInputIterator
Opid(167) Some(Opid(5)) Some(0ns) YieldInto
Opid(168) Some(Opid(5)) Some(700ns) YieldFrom(ResolveCoercion)
Opid(169) Some(Opid(5)) None AdvanceInputIterator
Opid(170) Some(Opid(5)) Some(100ns) YieldInto
Opid(171) Some(Opid(5)) Some(400ns) YieldFrom(ResolveCoercion)
Opid(172) Some(Opid(6)) Some(1.9µs) YieldInto
Opid(173) Some(Opid(6)) Some(2.2µs) YieldFrom(ResolveProperty)
Opid(174) Some(Opid(7)) Some(3.1µs) YieldInto
Opid(175) Some(Opid(7)) Some(3.4µs) YieldFrom(ResolveProperty)
Opid(176) None Some(5.3µs) ProduceQueryResult

Opid(177) Some(Opid(7)) None AdvanceInputIterator
Opid(178) Some(Opid(6)) None AdvanceInputIterator
Opid(179) Some(Opid(5)) None AdvanceInputIterator
Opid(180) Some(Opid(5)) Some(0ns) YieldInto
Opid(181) Some(Opid(5)) Some(900ns) YieldFrom(ResolveCoercion)
Opid(182) Some(Opid(5)) None AdvanceInputIterator
Opid(183) Some(Opid(155)) None OutputIteratorExhausted
Opid(184) Some(Opid(4)) None AdvanceInputIterator
Opid(185) Some(Opid(152)) None OutputIteratorExhausted
Opid(186) Some(Opid(3)) None AdvanceInputIterator
Opid(187) Some(Opid(149)) None OutputIteratorExhausted
Opid(188) Some(Opid(2)) None AdvanceInputIterator
Opid(189) Some(Opid(1)) Some(0ns) YieldFrom(ResolveStartingVertices)
Opid(190) Some(Opid(2)) Some(400ns) YieldInto
Opid(191) Some(Opid(2)) Some(900ns) YieldFrom(ResolveNeighborsOuter)
Opid(192) Some(Opid(191)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(193) Some(Opid(3)) Some(3.3µs) YieldInto
Opid(194) Some(Opid(3)) Some(4µs) YieldFrom(ResolveNeighborsOuter)
Opid(195) Some(Opid(194)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(196) Some(Opid(4)) Some(21.5µs) YieldInto
Opid(197) Some(Opid(4)) Some(22.3µs) YieldFrom(ResolveNeighborsOuter)
Opid(198) Some(Opid(197)) Some(0ns) YieldFrom(ResolveNeighborsInner)
Opid(199) Some(Opid(5)) Some(24.4µs) YieldInto
Opid(200) Some(Opid(5)) Some(27.5µs) YieldFrom(ResolveCoercion)
Opid(201) Some(Opid(5)) None AdvanceInputIterator
Opid(202) Some(Opid(5)) Some(100ns) YieldInto
Opid(203) Some(Opid(5)) Some(600ns) YieldFrom(ResolveCoercion)
Opid(204) Some(Opid(6)) Some(30.2µs) YieldInto
Opid(205) Some(Opid(6)) Some(30.5µs) YieldFrom(ResolveProperty)
Opid(206) Some(Opid(7)) Some(35.1µs) YieldInto
Opid(207) Some(Opid(7)) Some(35.7µs) YieldFrom(ResolveProperty)
Opid(208) None Some(36.4µs) ProduceQueryResult

Opid(209) Some(Opid(7)) None AdvanceInputIterator
Opid(210) Some(Opid(6)) None AdvanceInputIterator
Opid(211) Some(Opid(5)) None AdvanceInputIterator
Opid(212) Some(Opid(5)) Some(0ns) YieldInto
Opid(213) Some(Opid(5)) Some(400ns) YieldFrom(ResolveCoercion)
Opid(214) Some(Opid(5)) None AdvanceInputIterator
Opid(215) Some(Opid(5)) Some(0ns) YieldInto
Opid(216) Some(Opid(5)) Some(600ns) YieldFrom(ResolveCoercion)
Opid(217) Some(Opid(6)) Some(1.9µs) YieldInto
Opid(218) Some(Opid(6)) Some(2.3µs) YieldFrom(ResolveProperty)
Opid(219) Some(Opid(7)) Some(2.8µs) YieldInto
Opid(220) Some(Opid(7)) Some(3.2µs) YieldFrom(ResolveProperty)
Opid(221) None Some(3.9µs) ProduceQueryResult

Opid(222) Some(Opid(7)) None AdvanceInputIterator
Opid(223) Some(Opid(6)) None AdvanceInputIterator
Opid(224) Some(Opid(5)) None AdvanceInputIterator
Opid(225) Some(Opid(197)) None OutputIteratorExhausted
Opid(226) Some(Opid(4)) None AdvanceInputIterator
Opid(227) Some(Opid(194)) None OutputIteratorExhausted
Opid(228) Some(Opid(3)) None AdvanceInputIterator
Opid(229) Some(Opid(191)) None OutputIteratorExhausted
Opid(230) Some(Opid(2)) None AdvanceInputIterator
Opid(231) Some(Opid(1)) None OutputIteratorExhausted
Opid(232) Some(Opid(2)) None InputIteratorExhausted
Opid(233) Some(Opid(2)) None OutputIteratorExhausted
Opid(234) Some(Opid(3)) None InputIteratorExhausted
Opid(235) Some(Opid(3)) None OutputIteratorExhausted
Opid(236) Some(Opid(4)) None InputIteratorExhausted
Opid(237) Some(Opid(4)) None OutputIteratorExhausted
Opid(238) Some(Opid(5)) None InputIteratorExhausted
Opid(239) Some(Opid(5)) None OutputIteratorExhausted
Opid(240) Some(Opid(6)) None InputIteratorExhausted
Opid(241) Some(Opid(6)) None OutputIteratorExhausted
Opid(242) Some(Opid(7)) None InputIteratorExhausted
Opid(243) Some(Opid(7)) None OutputIteratorExhausted
""".strip().split("\n")

times = data[:2]
hierarchy = data[2:data.index("")]
# print("\n".join(hierarchy))
linear = data[data.index("") + 1:]
print("\n".join(linear))
# Out:
# Opid(1) None None Call(ResolveStartingVertices(Vid(1)))
# Opid(2) None None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
# Opid(3) None None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
# Opid(4) None None Call(ResolveNeighbors(Vid(1), "Number", Eid(1)))
# Opid(5) None None Call(ResolveCoercion(Vid(2), "Number", "Prime"))
# Opid(6) None None Call(ResolveProperty(Vid(2), "Prime", "value"))
# Opid(7) None None Call(ResolveProperty(Vid(1), "Number", "value"))
# Opid(8) Some(Opid(7)) None AdvanceInputIterator
# Opid(9) Some(Opid(6)) None AdvanceInputIterator
# Opid(10) Some(Opid(5)) None AdvanceInputIterator
# Opid(11) Some(Opid(4)) None AdvanceInputIterator
# Opid(12) Some(Opid(3)) None AdvanceInputIterator
# Opid(13) Some(Opid(2)) None AdvanceInputIterator
# Opid(14) Some(Opid(1)) Some(2.3µs) YieldFrom(ResolveStartingVertices)
# Opid(15) Some(Opid(2)) Some(10µs) YieldInto
# Opid(16) Some(Opid(2)) Some(31.1µs) YieldFrom(ResolveNeighborsOuter)
# ...

# %%
with open("enum_missing.ptrace.txt") as fd:
    data = fd.read().strip().split("\n")

linear = data
print(len(linear), "operations")
# Out:
# 6621 operations

# %%
from collections import defaultdict

groups = []
group = []
for line in linear:
    if line == "":
        groups.append(group)
        group = []
    else:
        group.append(line)
groups.append(group)

print("Ignoring Call. This is definitely wrong, and temporary.")
for group in groups[:-1]:
    ops = {}
    advances = []
    for i in range(len(group)):
        line = group[i]
    
        parts = line.split(" ")
        for j in range(len(parts)):
            part = parts[j]
            if part.startswith("Some("):
                parts[j] = part.removeprefix("Some(").removesuffix(")")
        
        ops[parts[0]] = tuple(parts)
        group[i] = tuple(parts)

        if parts[3] == "AdvanceInputIterator":
            advances.append((parts[0], i))


    advids = set(a[0] for a in advances)
    adv_pars = set(ops[a[0]][1] for a in advances)
    op_order = list(ops.keys())
    end = len(op_order) - 2  # -2 to skip ProduceQueryResult
    
    print(advids)
    print(adv_pars)

    def munch(advid, pos, end, regions):
        for idx in range(end, pos, -1):
            opid = op_order[idx]
            if opid in advids:
                # Somebody else's region. If we haven't already covered it,
                # munch inwards.
                regions[advid] = (advid, pos, (idx + 1, end))
                if opid not in regions:
                    # print(opid, idx, idx - 1, regions)
                    return munch(opid, 0, idx - 1, regions)
                else:
                    return idx

            op = ops[opid]
            if op[1] != ops[advid][1] and op[1] in adv_pars:
                break
    
        regions[advid] = (advid, pos, (idx + 1, end))
        return idx

        
    # Associate each advance with a block of code.
    # regions = {}
    # for advid, pos in (advances):
    #     if advid not in regions:
    #         end = munch(advid, pos, end, regions)

    # regions = {}
    # def munch2(start, end, regions):
    #     if start == end:
    #         return
    
    #     for i in range(start, end + 1):
    #         opid = op_order[i]
    #         op = ops[opid]
    #         if op[3] == "AdvanceInputIterator":
    #             print(opid)
    #             munch2(i + 1, end, regions)
    #             break
    
    # munch2(0, len(op_order) - 1, regions)
    # for row in regions.values():
    #     print(row)
    owners = {}
    callstack = []
    neighbors_depth = 0
    for i, opid in enumerate(op_order):
        op = ops[opid]

        # The previous function in the callstack is calling into this
        # iterator.
        if op[3] == "AdvanceInputIterator":
            callstack.append( opid )
            assert owners.get(callstack[-1], False) is False, str(opid)
            owners[callstack[-1]] = []
        elif op[3] == "YieldInto":
            owners[callstack[-1]].append(opid)
        elif op[3] == "OutputIteratorExhausted":
            owners[callstack[-1]].append(opid)
            # callstack.pop()
        elif op[3].startswith("YieldFrom"):
            if op[3] == "YieldFrom(ResolveNeighborsOuter)":
                owners[callstack[-1]].append(opid)
                callstack.append( opid )
                
                assert owners.get(callstack[-1], False) is False, str(opid)
                owners[callstack[-1]] = []
            elif op[3] == "YieldFrom(ResolveNeighborsInner)":
                # TODO: Handle multiple ResolveNeighborsInner
                # TODO: Handle nested ResolveNeighborsInner and Outer.
                owners[callstack[-1]].append(opid)
                callstack.pop()
                callstack.pop()
            elif op[3] == "YieldFrom(ResolveStartingVertices)":
                owners[opid] = []
            else:
                owners[callstack[-1]].append(opid)
                callstack.pop()
        # print(f"Line {i+1}: {callstack}\n")

    for (k, vals) in sorted(owners.items(), key=lambda x: int(x[0][5:-1])):
        print(f"=== {k} === ")
        print(vals)

    # print(ops[final])
    # depth = 1
    # for advid in initial_advances:
    #     adv = ops[advid]
    #     parent = adv[1]  # advances must always have a parent.
    #     print("-" * depth, " ".join(adv))
    #     # FIXME: This fails for inline AdvanceInputIterator
    #     found = False
    #     for (opid, op) in reversed(ops.items()):
    #         if op[1] == parent:
    #             print("-" * depth, " ".join(op))
    #             found = True
    #             continue

    #         if found:
    #             break
    #     depth += 1
    # print("")
# Out:
# Ignoring Call. This is definitely wrong, and temporary.

# %%
# Preprocess data.
groups = []
group = []
for line in linear:
    if line == "":
        groups.append(group)
        group = []
    else:
        group.append(line)
groups.append(group)

for group in groups:
    for i in range(len(group)):
        line = group[i]
    
        parts = line.split(" ")
        for j in range(len(parts)):
            part = parts[j]
            if part.startswith("Some("):
                parts[j] = part.removeprefix("Some(").removesuffix(")")
        
        group[i] = tuple(parts)

# %%
class TraceReplay:
    def __init__(self):
        self._calls = []
        self._ops = {}
        self._hierarchy = defaultdict(list)
        self._roots = []

        self._callstack = []
        self._neighbors_stack = []
        self._index = -1
        self._last_yield = None

    @property
    def active_function(self):
        return self._callstack[self._index]

    def progress(self, op):
        """Progresses the internal state according to the operation."""
        (opid, parent, time, op_type) = op
        self._ops[opid] = (parent, time, op_type)
        if parent is not None:
            # parent must always exist otherwise there is an error.
            self._hierarchy[parent].append(opid)
        else:
            self._roots.append(opid)

        if op_type.startswith("Call"):
            # FIXME: Currently assumes that function calls are always evaluated
            # on top of the stack from wherever they are until exhausted.
            self._calls.append(opid)
            self._callstack.append(opid)
        elif op_type.startswith("AdvanceInputIterator"):
            if parent not in self._calls:
                print("AdvanceInputIterator called with non-function parent.\n\t Operation: ", op)
            elif parent != self.active_function and parent != self._last_yield:
                print("AdvanceInputIterator called with incorrect function stack.\n\t Operation:", op, "\n\t Stack:", self._callstack, "\n\t Index: ", self._index, "\n\t Last Yield: ", self._last_yield)

            # If the last yield provided invalid results (such as not being of the right type)
            # the function may be called again.
            if parent != self.active_function:
                self._index -= 1
                if self.active_function != self._last_yield:
                    print("Active function does not match the last yielded.\n\t Operation:", op, "\n\tStack:", self._callstack, "\n\t Index:", self._index)
            
            # We are not currently evaluating the function but it hasn't been exhausted yet.
            if self._index == -1:
                self._index = len(self._callstack) - 2
            else:
                self._index -= 1
        elif op_type.startswith("YieldFrom"):
            self._last_yield = parent
            if op_type == "YieldFrom(ResolveStartingVertices)":
                self._index += 1
            elif op_type == "YieldFrom(ResolveNeighborsOuter)":
                # ResolveNeighborsOuter creates its own iterator and thus
                # deserves to go on the stack. It should go one behind so
                # that the yield from ResolveNeighborsInner moves to the
                # parent properly.
                # self._callstack.insert(self._index, opid)

                # It goes on its own stack in order to avoid numerical
                # conflicts.
                self._neighbors_stack.append(opid)
            elif op_type == "YieldFrom(ResolveNeighborsInner)":
                if parent not in self._neighbors_stack:
                    print("Yielding from ResolveNeighborsInner without a valid parent.\n\tOperation:", op)
                # TODO: Is it possible to have multiple subsequent ResolveNeighborsInner?
                # Currently assume it is not possible.
                self._index += 1
            else:
                self._index += 1
        elif op_type.startswith("OutputIteratorExhausted"):
            pass
        elif op_type.startswith("YieldInto"):
            pass
        elif op_type.startswith("InputIteratorExhausted"):
            pass
        else:
            print("Unknown operation type:", op_type)
        
        

player = TraceReplay()
for i, op in enumerate(groups[0]):
    op = (op[0], op[1], op[2], " ".join(op[3:]))
    if i > 1490:
        print(i, op)
    player.progress(op)
# Out:
# 1491 ('Opid(1492)', 'Opid(9)', '2.6471ms', 'YieldFrom(ResolveProperty)')
# 1492 ('Opid(1493)', 'Opid(10)', '2.656ms', 'YieldInto')
# 1493 ('Opid(1494)', 'Opid(10)', '2.6626ms', 'YieldFrom(ResolveNeighborsOuter)')
# 1494 ('Opid(1495)', 'None', 'None', 'Call(ResolveNeighbors(Vid(6), "Crate", Eid(6)))')
# 1495 ('Opid(1496)', 'None', 'None', 'Call(ResolveCoercion(Vid(7), "Item", "Enum"))')
# 1496 ('Opid(1497)', 'None', 'None', 'Call(ResolveProperty(Vid(7), "Enum", "visibility_limit"))')
# 1497 ('Opid(1498)', 'None', 'None', 'Call(ResolveNeighbors(Vid(7), "Enum", Eid(7)))')
# 1498 ('Opid(1499)', 'None', 'None', 'Call(ResolveProperty(Vid(8), "ImportablePath", "path"))')
# 1499 ('Opid(1500)', 'Opid(1499)', 'None', 'AdvanceInputIterator(owner: ResolveProperty)')
# AdvanceInputIterator called with incorrect function stack.
# 	 Operation: ('Opid(1500)', 'Opid(1499)', 'None', 'AdvanceInputIterator(owner: ResolveProperty)')
# ...

# %%
print("Ignoring Call. This is definitely wrong, and temporary.")

class CallStack:
    def __init__(self) -> None:
        self._stack = []
        self._owners = {}

    def push(self, opid):
        if self._stack:
            self._owners[self.top][1].append(opid)
        self._stack.append(opid)
        # If the opid is already in the stack or has been pushed
        # we have a problem with id duplication.
        assert opid not in self._owners
        self._owners[opid] = [[], []]

    def add(self, opid):
        """Add the given operation to the owner of the top of the stack.

        If you want to push to the stack, use the push method instead.
        """
        self._owners[self.top][0].append(opid)

    def pop(self):
        self._stack.pop()

    @property
    def top(self):
        return self._stack[-1] 

    @property
    def owners(self):
        return self._owners

    def __str__(self):
        if self._stack:
            print("Printing callstack with a non-empty stack may produce erroneous results.")
        ret = ["Stack " + str(self._stack)]
        for (k, vals) in callstack.owners.items():
            ret.append(f"{k}: {vals}")
        return "\n".join(ret)

for group in groups:
    print("=== GROUP ===")
    ops = {p[0]: p for p in group}
    op_order = list(ops.keys())
    
    callstack = CallStack()
    neighbors_depth = 0
    last_resolve_neighbors = False
    for i, opid in enumerate(op_order):
        op = ops[opid]

        # The previous function in the callstack is calling into this
        # iterator.
        if op[3] == "AdvanceInputIterator":
            callstack.push( opid )
        elif op[3] == "YieldInto":
            callstack.add(opid)
        elif op[3] == "OutputIteratorExhausted":
            callstack.add(opid)
            # callstack.pop()
        elif op[3].startswith("YieldFrom"):
            if op[3] == "YieldFrom(ResolveNeighborsOuter)":
                callstack.add(opid)
                callstack.push(opid)
            elif op[3] == "YieldFrom(ResolveNeighborsInner)":
                # TODO: Handle multiple ResolveNeighborsInner
                # TODO: Handle nested ResolveNeighborsInner and Outer.
                if last_resolve_neighbors:
                    raise E("Multiple ResolveNeighborsInner in a row not yet supported.")
                callstack.add(opid)
                callstack.pop()
                callstack.pop()
                last_resolve_neighbors = True
                continue
            elif op[3] == "YieldFrom(ResolveStartingVertices)":
                callstack.owners[opid] = [[], []]
            else:
                callstack.add(opid)
                callstack.pop()
        elif op[3] == "InputIteratorExhausted":
            raise E("InputIteratorExhausted not implemented.")
    
        last_resolve_neighbors = False
        if i < 50:
            print(f"Line {i+1}: {callstack._stack}\n")

    # for (k, vals) in sorted(callstack.owners.items(), key=lambda x: int(x[0][5:-1])):
    #     print(f"=== {k} === ")
    #     print(vals)
    print(callstack)
# Out:
# Ignoring Call. This is definitely wrong, and temporary.
# === GROUP ===
# Line 1: []
#
# Line 2: []
#
# Line 3: []
#
# Line 4: []
#
# Line 5: []
#
# Line 6: []
#
# Line 7: []
#
# Line 8: []
#
# Line 9: []
#
# Line 10: []
#
# Line 11: []
#
# Line 12: []
#
# Line 13: []
#
# Line 14: []
#
# Line 15: []
#
# Line 16: []
#
# Line 17: []
#
# Line 18: []
#
# Line 19: []
#
# Line 20: []
#
# Line 21: []
#
# Line 22: []
#
# Line 23: []
#
# Line 24: []
#
# Line 25: []
#
# Line 26: []
#
# Line 27: []
#
# Line 28: []
#
# Line 29: []
#
# Line 30: []
#
# Line 31: []
#
# Line 32: []
# ------------------------------------------------------------
# IndexError                 Traceback (most recent call last)
# Cell In[6], line 59
#      57     callstack.push( opid )
#      58 elif op[3] == "YieldInto":
# ---> 59     callstack.add(opid)
#      60 elif op[3] == "OutputIteratorExhausted":
#      61     callstack.add(opid)
#
# Cell In[6], line 22, in CallStack.add(self, opid)
# ...

# %%
TEST_CASE_1 = callstack.owners

# %%
print(TEST_CASE_1)
assert callstack.owners == TEST_CASE_1
